# %% [markdown]
# # Edge List Structure - Estructura de Lista de Aristas
#
# Realice lo siguiente:
#   * Programe la representación de grafos mediante un la **Estructura de Lista de Aristas**.
#   * Mediante networkx muestre el resultado gráfico del gráfo.

# %%
#Importar networkx
import networkx as nx

# %%
#Lista de aristas
edge_list = [('A','B'), ('A','C'), ('A','D'),
            ('B','H'), ('B','E'),
            ('C','D'), ('C','F'),
            ('D','E'), ('D','G'), 
            ('E','H'), ('E','G'), 
            ('F','G')
           ]

# %% [markdown]
# ## Graficación

# %% [markdown]
# **1. Generando grafo a partir de la lista**

# %%
Grafo = nx.Graph(edge_list)

# %% [markdown]
# **2. Graficar**

# %%
nx.draw(Grafo, with_labels=True)
